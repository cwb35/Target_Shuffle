# %%
import pandas as pd
from sklearn.datasets import load_iris
from Target_Shuffle import Target_Shuffle
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
data = load_iris()

# %%
df = pd.DataFrame(data.data[:,:], columns=['Sepal Length', 'Sepal Width', 'Petal Length', 'Petal Width'])

# %%
df.head()
# Out:
#    Sepal Length  Sepal Width  Petal Length  Petal Width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
plt.scatter(df['Petal Length'].values, df['Petal Width'].values)

# %%
ts = Target_Shuffle()

# %%
ts.test_significance(1000, df, 'Petal Length', 'Petal Width')
# Out:
# The estimated p-value for relation between Petal Length and Petal Width is 0.0
# 0.0

# %%
ts.test_significance(1000, df, 'Sepal Length', 'Sepal Width')
# Out:
# The estimated p-value for relation between Sepal Length and Sepal Width is 0.17700000000000005
# 0.17700000000000005
